# %%
from filler import FillerGame

# Example usage
game = FillerGame(size = 4)

# %%
game.play_turn('B', 1)

# %%
# AI (Player 2) finds the best move
best_move_for_ai = game.find_best_move()
print(best_move_for_ai)
game.play_turn(best_move_for_ai, 2)
# Out:
# R

# %%
game.play_turn("O", 1)

# %%
best_move_for_ai = game.find_best_move()
print(best_move_for_ai)
game.play_turn(best_move_for_ai, 2)
# Out:
# B

# %%
game.play_turn('P', 1)

# %%
best_move_for_ai = game.find_best_move()
print(best_move_for_ai)
game.play_turn(best_move_for_ai, 2)
# Out:
# Y

# %%
game.play_turn('G', 1)

# %%
best_move_for_ai = game.find_best_move()
print(best_move_for_ai)
game.play_turn(best_move_for_ai, 2)
# Out:
# O
# Player 2, you have won!
